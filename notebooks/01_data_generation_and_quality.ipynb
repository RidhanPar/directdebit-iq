# %% [markdown]
# # 01 — Data Generation and Quality
#
# Generate the synthetic payments dataset and validate schema, missing values, status balance, and risk-pattern logic.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

import pandas as pd
from src import config

config.PROJECT_NAME
