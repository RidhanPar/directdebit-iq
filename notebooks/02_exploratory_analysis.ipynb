# %% [markdown]
# # 02 — Exploratory Analysis
#
# Explore payment success/failure patterns by day of week, merchant, bank type, country, balance band, and previous failure count.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

import pandas as pd
from src import config

config.PROJECT_NAME
