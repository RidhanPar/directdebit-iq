# %% [markdown]
# # 03 — Feature Engineering
#
# Create model-ready features such as new mandate flags, low balance flags, Monday collection flags, amount transforms, and merchant summaries.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

import pandas as pd
from src import config

config.PROJECT_NAME
